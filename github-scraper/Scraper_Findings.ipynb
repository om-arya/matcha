# %% [markdown]
# ## Showcases findings from Scrapes

# %%
import pandas as pd

# %%
df = pd.read_csv('github_matplotlib_audit_1.csv')

# %%
df.head()
# Out:
#                                          repo            filename pushed_date  \
# 0                           PoldiB/Matplotlib  Muenchen Wetter.py  2022-01-01
# 1  VivianYuan12138/python_matplotlib_learning      Python可视化教程.md  2022-01-01
# 2                 gulanaanwar/randomwalkgraph        rw_visual.py  2022-01-01
# 3                           harishcpu/CPU-Spy            graph.py  2022-01-01
# 4                           wilsonleong/Gantt            chart.py  2022-01-02
#
#                                                 code
# 0  import pandas as pd\nfrom matplotlib import py...
# 1  # Python可视化教程\n\n### Matplotlib介绍\n\n**Matplot...
# 2  import matplotlib.pyplot as plt \n\nfrom rando...
# 3  import matplotlib.pyplot as pyp\r\nimport matp...
# 4  # -*- coding: utf-8 -*-\r\n"""\r\nCreated on M...

# %%
len(df)
# Out:
# 14956

# %%
df.shape[0]
# Out:
# 14956
